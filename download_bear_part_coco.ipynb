# %% [markdown]
# <a href="https://colab.research.google.com/github/Pengyu-gis/MyDeepLearing/blob/main/download_bear_part_coco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fiftyone
# !pip install fiftyone-db-ubuntu2204
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 19.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.5/41.5 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.8/226.8 kB 21.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.9/108.9 kB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 603.6/603.6 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 kB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.5/192.5 kB 11.5 MB/s eta 0:00:00
# ...

# %%
import fiftyone as fo
import fiftyone.zoo as foz
# Out:
# Migrating database to v0.21.4
# INFO:fiftyone.migrations.runner:Migrating database to v0.21.4

# %%
import fiftyone.zoo as foz

# To download the COCO dataset for only the "bear" class
dataset = foz.load_zoo_dataset(
    "coco-2017",
    splits=["train", "validation"],
    label_types=["detections"],
    classes=["bear"],
    # max_samples=50,
)
# Out:
# ...
# INFO:fiftyone.zoo.datasets:Downloading split 'train' to '/root/fiftyone/coco-2017/train' if necessary
# ...
# INFO:fiftyone.utils.coco:Downloading annotations to '/root/fiftyone/coco-2017/tmp-download/annotations_trainval2017.zip'
#  100% |██████|    1.9Gb/1.9Gb [5.8s elapsed, 0s remaining, 359.0Mb/s]
# INFO:eta.core.utils: 100% |██████|    1.9Gb/1.9Gb [5.8s elapsed, 0s remaining, 359.0Mb/s]
# Extracting annotations to '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# INFO:fiftyone.utils.coco:Extracting annotations to '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# ...
# INFO:fiftyone.utils.coco:Downloading 960 images
#  100% |██████████████████| 960/960 [3.5m elapsed, 0s remaining, 4.8 images/s]
# INFO:eta.core.utils: 100% |██████████████████| 960/960 [3.5m elapsed, 0s remaining, 4.8 images/s]
# Writing annotations for 960 downloaded samples to '/root/fiftyone/coco-2017/train/labels.json'
# ...

# %%
# Visualize the dataset in the FiftyOne App
session = fo.launch_app(dataset)
# Out:
# <style>
#
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# body, html {
#   margin: 0;
#   padding: 0;
#   width: 100%;
# }
#
# #focontainer-7eaab50b-cd76-4356-8a52-80460a2c68eb {
#   position: relative;
#   height: px;
#   display: block !important;
# }
# #foactivate-7eaab50b-cd76-4356-8a52-80460a2c68eb {
#   font-weight: bold;
#   cursor: pointer;
#   font-size: 24px;
#   border-radius: 3px;
#   text-align: center;
#   padding: 0.5em;
#   color: rgb(255, 255, 255);
#   font-family: "Palanquin", sans-serif;
#   position: absolute;
#   left: 50%;
#   top: 50%;
#   width: 160px;
#   margin-left: -80px;
#   margin-top: -23px;
#   background: hsla(210,11%,15%, 0.8);
#   border: none;
# }
# #foactivate-7eaab50b-cd76-4356-8a52-80460a2c68eb:focus {
#   outline: none;
# }
# #fooverlay-7eaab50b-cd76-4356-8a52-80460a2c68eb {
#   width: 100%;
#   height: 100%;
#   background: hsla(208, 7%, 46%, 0.7);
#   position: absolute;
#   top: 0;
#   left: 0;
# ...

# %%
# !zip -r /content/coco-2017-train.zip /root/fiftyone/coco-2017/train
# !zip -r /content/coco-2017-validation.zip /root/fiftyone/coco-2017/validation
# Out:
#   adding: root/fiftyone/coco-2017/train/ (stored 0%)
#   adding: root/fiftyone/coco-2017/train/labels.json (deflated 68%)
#   adding: root/fiftyone/coco-2017/train/data/ (stored 0%)
#   adding: root/fiftyone/coco-2017/train/data/000000226461.jpg (deflated 1%)
#   adding: root/fiftyone/coco-2017/train/data/000000504280.jpg (deflated 0%)
#   adding: root/fiftyone/coco-2017/train/data/000000317241.jpg (deflated 0%)
#   adding: root/fiftyone/coco-2017/train/data/000000166706.jpg (deflated 0%)
#   adding: root/fiftyone/coco-2017/train/data/000000186124.jpg (deflated 0%)
#   adding: root/fiftyone/coco-2017/train/data/000000106585.jpg (deflated 0%)
#   adding: root/fiftyone/coco-2017/train/data/000000321092.jpg (deflated 0%)
#   adding: root/fiftyone/coco-2017/train/data/000000218255.jpg (deflated 0%)
#   adding: root/fiftyone/coco-2017/train/data/000000238839.jpg (deflated 0%)
#   adding: root/fiftyone/coco-2017/train/data/000000211204.jpg (deflated 1%)
# ...

# %%
from google.colab import files
files.download("/content/coco-2017-train.zip")

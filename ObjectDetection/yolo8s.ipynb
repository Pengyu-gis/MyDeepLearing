# %% [markdown]
# <a href="https://colab.research.google.com/github/Pengyu-gis/MyDeepLearing/blob/main/ObjectDetection/yolo8s.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U ultralyticsplus==0.0.14

# %%
from ultralyticsplus import YOLO, render_result

# load model
model = YOLO('ultralyticsplus/yolov8s')

# set model parameters
model.overrides['conf'] = 0.25  # NMS confidence threshold
model.overrides['iou'] = 0.45  # NMS IoU threshold
model.overrides['agnostic_nms'] = False  # NMS class-agnostic
model.overrides['max_det'] = 1000  # maximum number of detections per image

# %%
# set image
image = 'https://parismatch.be/app/uploads/2017/12/titanic____d__couvrez_quel_acteur_aurait_pu_incarner_jack_dans_le_film_2683.jpeg_north_1200x_white.jpg'

# perform inference
results = model.predict(image)

# observe results
print(results[0].boxes)
render = render_result(model=model, image=image, result=results[0])
render.show()
# Out:
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# ...
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# ...
